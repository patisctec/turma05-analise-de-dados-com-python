# %% [markdown]
# ## Listas  ## Tuplas ## dicionarios

# %%
# lista "[]"

nome = "claudio"

# %%
alunos = ["Pati", "Aline", "Sara", "Carlos"]

print (alunos)
# Out:
# ['Pati', 'Aline', 'Sara', 'Carlos']

# %%
#dicionários
aluno = {
    "nome": "Professor",
    "idade": 40,
    "disciplina": "Python"
}

print (aluno ["idade"])
# Out:
# 40

# %%
aluno ["idade"] = 20

print (aluno)
# Out:
# {'nome': 'Professor', 'idade': 20, 'disciplina': 'Python'}
