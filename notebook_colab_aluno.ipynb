# %% [markdown]
# # Semana 03 — Versionamento (Git/GitHub) e Python Local
#
# **Curso:** Análise de Dados com Python — SENAI (Turma T5)
# **UC (MSEP):** Manipulação de Dados com Python e SQL (150h) — Bloco 2, Semanas 03 e 04
#
# Você já sabe programar lógica (Semana 02). Esta semana, além de formalizar o versionamento com Git/GitHub e conhecer o ambiente local (Python + VS Code), você aprende a guardar **vários valores organizados** em uma única estrutura: listas, tuplas e dicionários.
#
# > Em cada tópico abaixo: **2 exemplos resolvidos** + **1 atividade prática** para você fazer sozinho(a).

# %% [markdown]
# ---
# ### 🟢 Abertura — Semana 03: Versionamento e Python Local
#
# Nas semanas 01–02 você aprendeu a programar no Colab. <strong>Hoje você aprende a não perder seu trabalho</strong> e a trabalhar com Python instalado na sua máquina.
#
# **O que você vai aprender hoje:**
# - Usar Git e GitHub para versionar seu código e colaborar com outros
# - Instalar Python e VS Code para trabalhar localmente
# - Trabalhar com listas, tuplas e dicionários — as estruturas de dados essenciais

# %% [markdown]
# ---
# ## 1. Configurando seu Ambiente de Desenvolvimento
#
# Antes de versionar código, você precisa das ferramentas instaladas na sua máquina. Siga o passo a passo detalhado no **material HTML** — aqui você encontra os pontos críticos e os comandos de verificação.
#
# 📌 **Ordem de instalação:** 🐍 Python → 💻 VS Code → 🔧 Git → ✅ Verificação

# %% [markdown]
# ### Parte A — Instalar o Python
#
# 1. Acesse [python.org/downloads/windows](https://www.python.org/downloads/windows/) e baixe **Windows installer (64-bit)** da versão mais recente do Python 3
# 2. Execute o arquivo baixado — **antes de clicar em Install Now**:
#    ☑ Marque **"Add python.exe to PATH"** ← **erro mais comum da semana**: esquecer isso obriga a reinstalar do zero
# 3. Clique em **Install Now**, aguarde e clique em **Close**
#
# > Se após instalar o terminal não reconhecer `python`, reinicie o computador e tente de novo.

# %%
# Verifique se o Python foi instalado e está disponível no PATH
# (rode no terminal do VS Code ou aqui no Colab para comparar)
# !python --version
# !pip --version
# Out:
# Python 3.14.3
# pip 26.1.2 from C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip (python 3.13)

# %% [markdown]
# ### Parte B — Instalar o VS Code
#
# Baixe em [code.visualstudio.com/download](https://code.visualstudio.com/download) → **User Installer x64**.
# Na tela "Tarefas Adicionais", marque **todas** as opções (incluindo "Adicionar ao PATH").
#
# Após instalar, abra o VS Code e instale as **extensões obrigatórias** (ícone 🧩 na barra lateral ou `Ctrl+Shift+X`):
#
# | Extensão | Autor | Por quê é obrigatória |
# |---|---|---|
# | **Python** | Microsoft | Executa `.py` com ▶, IntelliSense, erros em tempo real |
# | **Jupyter** | Microsoft | Abre e executa notebooks `.ipynb` no VS Code |
#
# Extras recomendados: **Material Icon Theme** (Philipp Kief), **Python Indent** (Kevin Rose), **GitLens** (GitKraken), **Rainbow CSV** (mechatroner).
#
# Para conectar o VS Code ao Python que você instalou: `Ctrl+Shift+P` → `Python: Select Interpreter` → escolha `Python 3.x.x`.
#
# ---
#
# ### Parte C — Instalar o Git e Configurar sua Identidade
#
# Baixe em [git-scm.com/download/win](https://git-scm.com/download/win) — o download começa automaticamente.
# Durante o instalador, preste atenção em **duas telas**:
#
# 1. **"Choosing the default editor"** → abra o **dropdown** e selecione `Use Visual Studio Code as Git's default editor`
# 2. **"Adjusting the name of the initial branch"** → marque "Override" e escreva **`main`** no campo de texto
#    *(O GitHub usa `main` desde 2020 — usar o mesmo nome evita conflitos no push.)*
#
# Nas demais telas: **Next → Install → Finish**.
#
# Após instalar, configure sua identidade no Git (próxima célula de código):

# %%
# Configure sua identidade no Git — substitua com seus dados reais
# Use o mesmo e-mail que você vai usar no GitHub

# !git config --global user.name "Seu Nome Completo"
# !git config --global user.email "seu@email.com"

# Confirme que foram salvas corretamente:
# !git config --global user.name
# !git config --global user.email
# Out:
# Seu Nome Completo
# seu@email.com

# %%
# Verificação completa do ambiente — rode no terminal do VS Code ou aqui no Colab
# !python --version   # deve mostrar Python 3.x.x
# !pip --version      # deve mostrar pip 24.x.x
# !git --version      # deve mostrar git version 2.x.x.windows.x

# O comando abaixo só funciona no terminal LOCAL (não no Colab):
# code --version    # x.xx.x (VS Code)

# Se os quatro responderem com versões: ambiente pronto!
# Out:
# Python 3.14.3
# pip 26.1.2 from C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip (python 3.13)
#
# git version 2.55.0.windows.2

# %% [markdown]
# ---
# ✅ **Checagem rápida — antes de avançar:**
# Você consegue abrir o terminal do VS Code e rodar `python --version` e `git --version` na sua máquina?
#
# ---

# %% [markdown]
# ---
# ## 2. Git e GitHub — Fluxo Completo no VS Code (Windows)
#
# > 📌 **Repositório da turma × seu repositório:**
# > `cfneves/turma05-analise-de-dados-com-python` é para você **consultar o material do curso**. O repositório que você cria agora é o **seu** — onde fica o código que você escreve.
#
# Todos os comandos são para o **Terminal integrado do VS Code** (PowerShell no Windows).
#
# ### Conceitos essenciais
#
# | Conceito | O que é | Analogia |
# |---|---|---|
# | **Repositório** | Pasta do projeto versionada pelo Git | A caixa onde você guarda tudo |
# | **Commit** | Um "ponto de salvamento" das mudanças, com mensagem | Fotografia + legenda do estado atual |
# | **Clone** | Copiar um repositório do GitHub para o computador | Baixar o projeto completo |
# | **Push** | Enviar seus commits do computador para o GitHub | Salvar na nuvem |
# | **Pull** | Baixar as atualizações do GitHub para o computador | Sincronizar o arquivo |
#
# ---
#
# ### 🔵 FASE 1 — Configuração Inicial (apenas uma vez)
#
# **Passo 1 — Criar repositório no GitHub**
# Crie um repositório **público**, **sem README**. Nome sugerido: `gitsenai`
#
# > 💡 Use letras minúsculas e hífens. Sem espaços, sem acentos. Ex: `analise-de-dados`
#
# **Passo 2 — Abrir o Explorador de Arquivos**
# Crie uma pasta local: `C:\Users\SEU_USUARIO\Documents\git_aula`
#
# > 💡 *Este Computador → Documentos → botão direito → Nova Pasta → **git_aula***
#
# **Passo 3 — Entrar na pasta local**
# Abra a pasta `git_aula` no Explorador de Arquivos.
#
# **Passo 4 — Abrir o Terminal no VS Code**
# Com a pasta `git_aula` aberta no VS Code: **Terminal → New Terminal**.
#
# **Passo 5 — Clonar o repositório do GitHub**
# ```
# git clone https://github.com/SEU_USUARIO/gitsenai.git
# ```
# Será criada a pasta `gitsenai` dentro de `git_aula`.
#
# **Passo 6 — Entrar no repositório**
# ```
# cd gitsenai
# ```
#
# > ⚠️ **Todos os próximos comandos devem ser executados dentro da pasta `gitsenai`.**
#
# 📁 Estrutura até aqui:
# ```
# Documentos/
# └── git_aula/         ← pasta local que você criou
#     └── gitsenai/     ← repositório clonado
# ```

# %% [markdown]
# ### 🟢 FASE 2 — Criar e Commitar a Estrutura Inicial (primeiro push)
#
# **Passo 1 — Criar duas pastas dentro do repositório**
# ```
# mkdir Aula01
# mkdir Aula02
# ```
#
# **Passo 2 — Entrar na pasta Aula01**
# ```
# cd Aula01
# ```
#
# **Passo 3 — Criar um arquivo Python vazio**
# ```
# ni main.py
# ```
# (cria o arquivo vazio `main.py`)
#
# **Passo 4 — Voltar ao projeto principal**
# ```
# cd ..
# ```
#
# **Passo 5 — Entrar na pasta Aula02**
# ```
# cd Aula02
# ```
#
# **Passo 6 — Criar um arquivo Python vazio**
# ```
# ni arquivo.py
# ```
# (cria o arquivo vazio `arquivo.py`)
#
# **Passo 7 — Voltar ao projeto principal**
# ```
# cd ..
# ```
#
# **Passo 8 — README.md**
# O `README.md` já está no repositório remoto (GitHub). **Não é necessário criá-lo agora.**
#
# **Passo 9 — Inicializar o repositório Git local**
# ```
# git init
# ```
# Aparecerá uma pasta oculta `.git`.
#
# **Passo 10 — Verificar o status**
# ```
# git status
# ```
# Você verá todas as pastas e arquivos como "não rastreados".
#
# **Passo 11 — Adicionar todos os arquivos ao stage**
# ```
# git add .
# ```
# (o ponto `.` adiciona tudo de uma vez)
#
# **Passo 12 — Criar o primeiro commit**
# ```
# git commit -m "Criando meu primeiro commit"
# ```
#
# **Passo 13 — Enviar para o GitHub (primeiro push)**
# ```
# git push origin main
# ```
#
# > 🏆 **Parabéns!** Seu repositório `gitsenai` está publicado no GitHub com a estrutura inicial.
#
# 📁 Estrutura após o primeiro push:
# ```
# gitsenai/
# ├── Aula01/
# │   └── main.py
# ├── Aula02/
# │   └── arquivo.py
# └── README.md
# ```

# %% [markdown]
# ### 🟠 FASE 3 — Adicionar Novo Arquivo na Pasta Aula02 (segundo push)
#
# **Passo 1 — Entrar na pasta Aula02**
# ```
# cd Aula02
# ```
#
# **Passo 2 — Criar um novo arquivo Python**
# ```
# ni novo_arquivo.py
# ```
#
# **Passo 3 — Voltar ao projeto principal**
# ```
# cd ..
# ```
#
# **Passo 4 — Verificar alterações**
# ```
# git status
# ```
# Você verá `novo_arquivo.py` como "não rastreado".
#
# **Passo 5 — Adicionar ao stage**
# ```
# git add .
# ```
# (ou só o arquivo específico: `git add Aula02/novo_arquivo.py`)
#
# **Passo 6 — Criar commit**
# ```
# git commit -m "Adiciona novo arquivo na pasta Aula02"
# ```
#
# **Passo 7 — Enviar para o GitHub**
# ```
# git push
# ```
#
# > ⭐ Fase 3 concluída! Seu repositório foi atualizado com o novo arquivo.

# %%
# ── Referência de comandos — execute no TERMINAL do VS Code (PowerShell), não aqui ──

# FASE 2 — Criar estrutura e primeiro push
# mkdir Aula01
# mkdir Aula02
# cd Aula01
# ni main.py
# cd ..
# cd Aula02
# ni arquivo.py
# cd ..
# git init
# git status
# git add .
# git commit -m "Criando meu primeiro commit"
# git push origin main

# FASE 3 — Segundo push (novo arquivo)
# cd Aula02
# ni novo_arquivo.py
# cd ..
# git status
# git add .
# git commit -m "Adiciona novo arquivo na pasta Aula02"
# git push

# FASE 4 — Fluxo diário (repita sempre que alterar algo)
# git status
# git add .
# git commit -m "Descrição da alteração"
# git push

print("Referência de comandos Git — execute no terminal do VS Code, não aqui no Colab.")
# Out:
# Referência de comandos Git — execute no terminal do VS Code, não aqui no Colab.

# %% [markdown]
# ### ⬛ FASE 4 — Fluxo Diário para Atualizar o Repositório
#
# Sempre que fizer uma alteração nos seus arquivos, repita estes 5 passos:
#
# | Passo | Comando | O que faz |
# |---|---|---|
# | 1 | *(editar os arquivos no VS Code)* | Faça suas alterações |
# | 2 | `git status` | Veja o que foi modificado |
# | 3 | `git add .` | Adiciona tudo ao stage |
# | 4 | `git commit -m "Descrição da alteração"` | Salva no histórico |
# | 5 | `git push` | Publica no GitHub |
#
# ---
#
# ### 💡 Dicas importantes
#
# - Faça commits **pequenos e frequentes** — é mais fácil voltar a um ponto específico.
# - Escreva mensagens **claras e objetivas** — `"Corrige cálculo de média"` vale mais que `"Update"`.
# - Sempre rode `git status` antes de adicionar e commitar.
# - Salve seus arquivos no VS Code antes de rodar os comandos.
# - Em caso de erro: **leia a mensagem do Git** — ela quase sempre diz o que fazer.
#
# > ⚠️ Todos os comandos Git devem ser executados **dentro da pasta `gitsenai`** (repositório local).
#
# ---
#
# ### Resumo do fluxo completo
#
# ```
# 🐙 Criar repositório no GitHub
# 📥 git clone https://github.com/SEU_USUARIO/gitsenai.git
# 📁 cd gitsenai
# 🔧 mkdir Aula01 / mkdir Aula02 / ni main.py ...
# ⚙️  git init
# ➕  git add .
# ✅  git commit -m "Criando meu primeiro commit"
# ☁️  git push origin main          ← primeiro push
#
# ── nova alteração? ──────────────────────────
# ➕  git add .
# ✅  git commit -m "Descrição da alteração"
# ☁️  git push
#
# 🔄 Repetir sempre que houver novas alterações!
# ```

# %% [markdown]
# ---
# ✅ **Checagem rápida — antes de avançar para as estruturas de dados:**
# Você consegue fazer um `git add`, `git commit` e `git push` para o **seu** repositório no GitHub sem consultar o guia?
#
# ---

# %% [markdown]
# ## 1. Listas
#
# Uma **lista** é uma coleção de valores guardados em **sequência**, dentro de colchetes `[ ]`, separados por vírgulas. Você pode guardar qualquer tipo de dado: palavras, números, ou mistura dos dois.
#
# ```python
# frutas = ["maçã", "banana", "laranja"]   # lista de strings
# notas  = [8.5, 7.0, 9.5]                 # lista de números
# misto  = ["Ana", 25, True]               # lista misturada — funciona!
# ```
#
# ### Como acessar itens: índices
#
# Cada item tem uma **posição numérica** chamada **índice**, que começa em `0` (não em 1):
#
# | Item | `"maçã"` | `"banana"` | `"laranja"` |
# |---|---|---|---|
# | **Índice positivo** | 0 | 1 | 2 |
# | **Índice negativo** | -3 | -2 | -1 |
#
# - `frutas[0]` → `"maçã"` &nbsp; (primeiro item)
# - `frutas[-1]` → `"laranja"` &nbsp; (último item — funciona em qualquer lista, independente do tamanho)
#
# ### Principais funções e métodos
#
# | Recurso | O que faz | Exemplo | Resultado |
# |---|---|---|---|
# | `.append(valor)` | Adiciona um item ao **final** da lista | `frutas.append("uva")` | lista cresce 1 item |
# | `.insert(índice, valor)` | Insere um item numa **posição específica** | `frutas.insert(1, "uva")` | "uva" entra na posição 1 |
# | `.remove(valor)` | Remove a **primeira ocorrência** do valor | `frutas.remove("banana")` | só essa ocorrência some |
# | `.pop(índice)` | Remove e **retorna** o item da posição (ou o último, sem índice) | `frutas.pop()` | retorna e remove o último item |
# | `.sort()` | Ordena a lista em **ordem crescente** | `notas.sort()` | lista fica ordenada |
# | `len(lista)` | Retorna a **quantidade** de itens | `len(frutas)` | `3` |
# | `max(lista)` | Retorna o **maior** valor | `max(notas)` | `9.5` |
# | `min(lista)` | Retorna o **menor** valor | `min(notas)` | `7.0` |
#
# **Por que usar cada um (e quando):**
# - **`.append(valor)`** — acrescenta no final. Use quando a ordem de chegada não importa, só precisa guardar o novo item.
# - **`.insert(índice, valor)`** — acrescenta numa posição escolhida. Use quando a posição importa (ex.: uma tarefa urgente precisa entrar no topo da lista, não no final).
# - **`.remove(valor)`** — tira pelo **conteúdo**. Use quando você sabe *o que* quer tirar (o valor), mas não sabe (ou não importa) em que posição ele está.
# - **`.pop(índice)`** — tira e **devolve** o item removido. Use quando você ainda vai usar esse valor depois de tirá-lo da lista (`remove()` só descarta, `pop()` te entrega o valor).
# - **`.sort()`** — reordena a lista. Use quando a ordem de exibição ou de análise importa (ranking, lista alfabética, notas em ordem crescente).
#
# > 💡 **Lista é mutável** — você pode adicionar, remover e alterar itens depois de criá-la. Diferente da tupla, que você vai ver logo a seguir.
#
# ---
#
# ### 🔹 Exemplo 1 — Lista de compras
#
# Vamos criar uma lista, acessar o primeiro e o último item pelos índices, e testar os 5 métodos da tabela na prática — vendo o que cada um faz e em qual situação você usaria ele:

# %%
# (espaço para o código — construído ao vivo em aula)

compras = ["leite", "arroz", "feijão"]

print(compras [0])
print (compras[-1])  # último item da lista

compras.append("café")  # adiciona item no final da lista
print(compras)

#insert

compras.insert(0, "manteiga")  # adiciona item na posição 0
print(compras)


#.remove

compras.remove("feijão")  # remove item da lista
print(compras)  

#.pop

item_retirado = compras.pop()  # remove o último item da lista e retorna ele
print(f"Item retirado: {item_retirado}")
print(compras)

#.sort

compras.sort()  # ordena a lista em ordem alfabética
print(compras)
# Out:
# leite
# feijão
# ['leite', 'arroz', 'feijão', 'café']
# ['manteiga', 'leite', 'arroz', 'feijão', 'café']
# ['manteiga', 'leite', 'arroz', 'café']
# Item retirado: café
# ['manteiga', 'leite', 'arroz']
# ['arroz', 'leite', 'manteiga']

# %%
print(compras[10])  # tenta acessar um índice que não existe — gera erro
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(compras[10])  # tenta acessar um índice que não existe — gera erro
#
# IndexError: list index out of range

# %% [markdown]
# > ⚠️ **Veja como é um erro real do Python.** Depois de todas as operações acima, a lista `compras` ficou com 3 itens (índices 0 a 2). Se você pedir um índice que ela não tem, como `compras[10]`, o Python recusa e mostra `IndexError: list index out of range` — "índice fora do intervalo". Tente rodar `print(compras[10])` numa célula nova para ver o erro de verdade.

# %% [markdown]
# ### 🔹 Exemplo 2 — Calculando a média de uma lista de notas
#
# Agora veja como usar `len()` para contar os itens e `sum()` para somar todos os valores — combinando os dois, calculamos a média da turma em uma linha:

# %%
# (espaço para o código — construído ao vivo em aula)

notas = [7.5, 8.0, 6.5, 9.0, 5.5]

media = sum(notas) / len(notas)
print(f"Média das notas: {media:.2f}")
# Out:
# Média das notas: 7.30

# %%
notas = [7.5, "casa", 6.5, 9.0, 5.5]

media = sum(notas) / len(notas)
print(f"Média das notas: {media:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 notas = [7.5, "casa", 6.5, 9.0, 5.5]
#       2
# ----> 3 media = sum(notas) / len(notas)
#       4 print(f"Média das notas: {media:.2f}")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# ### ✏️ Atividade Prática 1 — Sua vez de programar
#
# Crie uma lista com 5 itens seus (podem ser nomes, números, o que quiser) e imprima o segundo e o último item usando índices.

# %%
# (espaço para o código — construído ao vivo em aula)

lista =["casa", "carro", "bicicleta", "ônibus", "avião"]

print(lista[1])  # acessa o segundo item da lista (índice 1)
print(lista[-1])  # acessa o último item da lista (índice -1)
# Out:
# carro
# avião

# %% [markdown]
# ### ✏️ Atividade 3-B — Adicionar elemento com `.append()`
#
# Crie uma lista com 3 nomes, adicione o **seu próprio nome** usando `.append()` e exiba a lista completa com o total de nomes.

# %%
# (espaço para o código — construído ao vivo em aula)

nomes =["Carla", "Carlos", "Claúdia"]

print(nomes)

nomes.append("Patricia")  # adiciona item no final da lista

print(nomes)

print(f"o total de nomes é: {len(nomes)}")
# Out:
# ['Carla', 'Carlos', 'Claúdia']
# ['Carla', 'Carlos', 'Claúdia', 'Patricia']
# o total de nomes é: 4

# %% [markdown]
# ### ✏️ Atividade 3-C — Inserir numa posição específica com `.insert()`
#
# Crie uma lista de 3 tarefas. Uma tarefa urgente chegou e precisa furar a fila — ela tem que aparecer na posição 0 (o início), não no final. Use `.insert()` para colocá-la lá e exiba a lista completa.

# %%
# (espaço para o código — construído ao vivo em aula)

tarefas = ["Lavar a louça", "Passar a varredora", "Fazer o almoço"]

print(tarefas)

tarefas.insert(0, "Limpar a casa")  # adiciona item na posição 0


print(tarefas)  

tarefas.sort()  # ordena a lista em ordem alfabética
print(tarefas)
# Out:
# ['Lavar a louça', 'Passar a varredora', 'Fazer o almoço']
# ['Limpar a casa', 'Lavar a louça', 'Passar a varredora', 'Fazer o almoço']
# ['Fazer o almoço', 'Lavar a louça', 'Limpar a casa', 'Passar a varredora']

# %% [markdown]
# ### ✏️ Atividade 3-D — Remover pelo conteúdo com `.remove()`
#
# A lista de presença abaixo tem um nome duplicado por engano. Use `.remove()` para tirar a duplicata (sem saber ou se importar com a posição) e exiba a lista corrigida.

# %%
# (espaço para o código — construído ao vivo em aula)

nomes = ["Alice", "Bob", "Charlie", "David", "Bob", "Eva", "Bob"]
print(nomes)

nomes.remove("Bob")  # remove a primeira ocorrência de "Bob"
print(nomes)
# Out:
# ['Alice', 'Bob', 'Charlie', 'David', 'Bob', 'Eva', 'Bob']
# ['Alice', 'Charlie', 'David', 'Bob', 'Eva', 'Bob']

# %% [markdown]
# ### ✏️ Atividade 3-E — Retirar e usar o valor com `.pop()`
#
# A fila de atendimento abaixo precisa chamar a **primeira** pessoa (ela é a próxima a ser atendida). Use `.pop(0)` para retirar essa pessoa da fila, guarde o nome numa variável (você vai usar esse valor na mensagem) e exiba quem foi chamado e como ficou a fila.

# %%
# (espaço para o código — construído ao vivo em aula)

fila_atendimento = ["Ana Meira", "Bruno Silva", "Carla Souza", "Daniela Costa", "Eduardo Lima"]

chamado = fila_atendimento.pop(0)  # remove e retorna o primeiro item da lista) 

print(f"Chamado: {chamado}")

print(f"Fila de atendimento: {fila_atendimento}")
# Out:
# Chamado: Ana Meira
# Fila de atendimento: ['Bruno Silva', 'Carla Souza', 'Daniela Costa', 'Eduardo Lima']

# %% [markdown]
# ### ✏️ Atividade 3-F — Ordenar com `.sort()`
#
# As notas da turma abaixo precisam ser exibidas em ordem crescente para o boletim. Use `.sort()` para ordenar a lista e exiba o resultado.

# %%
# (espaço para o código — construído ao vivo em aula)

turma = ["Vanessa", "Carla", "Patricia", "Carlos", "João"]

print(turma)

turma.sort()

print(turma)
# Out:
# ['Vanessa', 'Carla', 'Patricia', 'Carlos', 'João']
# ['Carla', 'Carlos', 'João', 'Patricia', 'Vanessa']

# %% [markdown]
# ---
# ## 2. Tuplas
#
# Uma **tupla** é parecida com uma lista, mas usa **parênteses** `( )` em vez de colchetes — e a diferença fundamental é que ela é **imutável**: depois de criada, os valores não podem ser alterados.
#
# ```python
# cores  = ("vermelho", "verde", "azul")   # tupla de strings
# ponto  = (10, 20)                         # coordenada x, y
# data   = (15, 3, 2005)                    # dia, mês, ano
# ```
#
# **Quando usar tupla em vez de lista?**
# Use tupla para dados que *não devem mudar nunca*: coordenadas geográficas, data de nascimento, configurações fixas de um sistema. A imutabilidade **protege o dado** de alterações acidentais — o Python recusa qualquer tentativa de mudança e lança um erro.
#
# > 💡 Tupla acessa itens pelos mesmos índices da lista: `ponto[0]` → `10`, `ponto[-1]` → `20`.
#
# ---
#
# ### 🔹 Exemplo 1 — Dados que não devem mudar
#
# Vamos criar uma tupla de coordenadas, acessar seus valores e, depois, tentar alterar um item para ver o erro que o Python lança:

# %%
# (espaço para o código — construído ao vivo em aula)

coordenadas = (10,20)

print(f"X = {coordenadas[0]}, Y = {coordenadas[1]}")

coordenadas = [0] = 99
# Out:
#   Cell In[38], line 7
#     coordenadas = [0] = 99
#                    ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# > ⚠️ **Veja como é um erro real do Python.** Remova o `#` da última linha da célula acima e execute — você vai ver `TypeError: 'tuple' object does not support item assignment` ("o objeto tupla não permite atribuição de item"). É a imutabilidade da tupla sendo aplicada na prática, não só explicada em texto.

# %% [markdown]
# ### 🔹 Exemplo 2 — Tupla para data de nascimento
#
# Uma data de nascimento nunca muda — caso perfeito para tupla. Veja como criar a tupla e extrair cada parte em variáveis separadas para montar uma frase com f-string:

# %%
# (espaço para o código — construído ao vivo em aula)

nascimento = (16, 7, 2026)

dia = nascimento[0]
mes = nascimento[1]
ano = nascimento[2]

print(f"Data de Nascimento é: {dia}/{mes}/{ano}")

print("A data de nascimento é: {}/{}/{}".format(dia, mes, ano))
# Out:
# Data de Nascimento é: 16/7/2026
# A data de nascimento é: 16/7/2026

# %% [markdown]
# ### ✏️ Atividade Prática 2 — Sua vez de programar
#
# Crie uma tupla com 3 valores que não devem mudar (ex.: data de nascimento) e imprima cada um deles.

# %%
# (espaço para o código — construído ao vivo em aula)

casamento = (5, 12, 2015)

print(f"Data de Casamento é: {casamento[0]}/{casamento[1]}/{casamento[2]}")

print("A data de casamento é: {}/{}/{}".format(casamento[0], casamento[1], casamento[2]))   

print(casamento)
# Out:
# Data de Casamento é: 5/12/2015
# A data de casamento é: 5/12/2015
# (5, 12, 2015)

# %% [markdown]
# ---
# ## 3. Dicionários
#
# Um **dicionário** guarda pares de **chave: valor** entre chaves `{ }`. Em vez de acessar por posição (como lista e tupla), você acessa pelo **nome da chave** — o que torna o código muito mais legível.
#
# ```python
# aluno = {"nome": "Ana", "nota": 9.5, "turma": "T5"}
# #         chave   valor   chave  valor  chave   valor
#
# print(aluno["nome"])   # "Ana"  — acesso pela chave, não pela posição
# print(aluno["nota"])   # 9.5
# ```
#
# | Recurso | O que faz | Exemplo |
# |---|---|---|
# | `dic["chave"]` | Acessa o valor pela chave | `aluno["nome"]` → `"Ana"` |
# | `dic["chave"] = novo` | Atualiza (ou cria) um valor | `aluno["nota"] = 10.0` |
#
# > 💡 **Dicionário vs. Lista:** lista usa posição (`0, 1, 2…`); dicionário usa nome (`"nome"`, `"nota"`). Use dicionário quando o *significado do campo* importa mais que a posição — por exemplo, para representar um cadastro, um produto ou um usuário.
#
# ---
#
# ### 🔹 Exemplo 1 — Cadastro de produto
#
# Vamos criar um dicionário de produto com três campos e acessar cada valor pelo nome da chave:

# %%
# (espaço para o código — construído ao vivo em aula)

produto = {
    'nome' : 'Mouse',
    'preco' : 45.00,
    'estoque' : 12
}

print(f"{produto['nome']} - custa R$ {produto['preco']:.2f} - Estoque: {produto['estoque']}")

print(f"Estoque disponível é: {produto['estoque']} unidades")
# Out:
# Mouse - custa R$ 45.00 - Estoque: 12
# Estoque disponível é: 12 unidades

# %% [markdown]
# ### 🔹 Exemplo 2 — Atualizando um valor no dicionário
#
# O dicionário é **mutável** — diferente da tupla, você pode alterar o valor de uma chave a qualquer momento. Veja como atualizar a nota de um aluno e comparar o antes e o depois:

# %%
# (espaço para o código — construído ao vivo em aula)

aluno = {
    "nome": "Patricia", 
    "nota": 7.0,
}

print(f"A nota atual é: {aluno['nota']}")


aluno["nota"] = 9.0  # altera o valor da chave "nota", pq dicionário é mutável
print(f"A nota corrigida é: {aluno['nota']}")
# Out:
# A nota atual é: 7.0
# A nota corrigida é: 9.0

# %% [markdown]
# ### ✏️ Atividade Prática 3 — Sua vez de programar
#
# Crie um dicionário representando você (`nome`, `idade`, `curso`) e imprima cada valor acessando pela chave.

# %%
# (espaço para o código — construído ao vivo em aula)

dicionario = {
    "nome": "Patricia",
    "idade": 43 ,
    "curso": "Análise de Dados com Python" 
}

print(f"Nome: {dicionario['nome']}, Idade: {dicionario['idade']}, Curso: {dicionario['curso']}")
# Out:
# Nome: Patricia, Idade: 43, Curso: Análise de Dados com Python

# %% [markdown]
# ---
# ## 4. Combinando tudo: o carrinho de compras
#
# Um carrinho de compras é uma **lista de dicionários** — cada item tem produto, preço e quantidade.

# %%
# (espaço para o código — construído ao vivo em aula)

carrinho = [
    {"produto": "caderno", "preco": 12.50, "quantidade":2},
    {"produto": "lapis", "preco": 2.00, "quantidade":5},
    {"produto": "borracha", "preco": 1.50, "quantidade":3}
]

total = 0
for item in carrinho:
    subtotal = item["preco"] * item["quantidade"]
    total += subtotal
    print(f"Produto: {item['produto']}, Preço: R$ {item['preco']:.2f}, Quantidade: {item['quantidade']}, Subtotal: R$ {subtotal:.2f}")
    
print(f"Total da compra: R$ {total:.2f}")
# Out:
# Produto: caderno, Preço: R$ 12.50, Quantidade: 2, Subtotal: R$ 25.00
# Produto: lapis, Preço: R$ 2.00, Quantidade: 5, Subtotal: R$ 10.00
# Produto: borracha, Preço: R$ 1.50, Quantidade: 3, Subtotal: R$ 4.50
# Total da compra: R$ 39.50

# %% [markdown]
# ### ✏️ Atividade Prática 4 — Sua vez de programar
#
# Crie o seu próprio carrinho de compras (lista de dicionários) com pelo menos 3 itens e calcule o total.

# %%
# (espaço para o código — construído ao vivo em aula)

carrinho_pati = [
    {"produto": "fone", "preco": 25.50, "quantidade":3},
    {"produto": "rimel", "preco": 45.00, "quantidade":4},
    {"produto": "batom", "preco": 32.00, "quantidade":2}
]

total = 0
for item in carrinho_pati:
    subtotal = item["preco"] * item["quantidade"]
    total += subtotal
    print(f"Produto: {item['produto']}, Preço: R$ {item['preco']:.2f}, Quantidade: {item['quantidade']}, Subtotal: R$ {subtotal:.2f}")

print(f"Total da compra: R$ {total:.2f}")
# Out:
# Produto: fone, Preço: R$ 25.50, Quantidade: 3, Subtotal: R$ 76.50
# Produto: rimel, Preço: R$ 45.00, Quantidade: 4, Subtotal: R$ 180.00
# Produto: batom, Preço: R$ 32.00, Quantidade: 2, Subtotal: R$ 64.00
# Total da compra: R$ 320.50

# %% [markdown]
# ---
# ### 🏁 Fechamento — Semana 03
#
# **Nesta semana você aprendeu:**
# - Git instalado e funcionando: commit, push e pull sem medo
# - Ambiente local configurado com Python e VS Code
# - Listas, tuplas e dicionários como estruturas para organizar dados
#
# **Próxima semana:** Semana 04 — Manipulação de Arquivos e Modularização: ler dados de arquivos CSV/JSON e criar funções reutilizáveis.

# %% [markdown]
# ---
# ## 5. Treino em Squads — Sexta-feira (Encontro 3)
#
# Esta seção é usada **em sala (ou em salas remotas/breakout)** na sexta-feira. A turma se divide em squads, e cada squad recebe um mini-projeto diferente, com a missão de **versioná-lo em conjunto**:
#
# | Squad | Mini-projeto |
# |---|---|
# | A | Lista de tarefas (lista) — adicionar uma nova tarefa e exibir a lista completa |
# | B | Cadastro de produtos (lista de dicionários) — adicionar um produto novo |
# | C | Lista de compras (lista) — remover um item duplicado |
# | D | Agenda de contatos (dicionário) — atualizar o telefone de um contato |
# | E | Estoque (tupla x lista) — corrigir um bug de cálculo de total |
#
# Cada integrante do squad faz pelo menos 1 commit no Git com uma mensagem clara. O squad apresenta o histórico de commits (`git log`), não só o resultado final.

# %% [markdown]
# ### Código inicial — rode só a célula do squad que você recebeu
#
# Cada squad já tem um código de partida pronto abaixo (não precisa escrever do zero). Edite a célula do seu squad, faça pelo menos 1 commit por integrante, e teste no Colab antes de apresentar.

# %%
# SQUAD A — Lista de tarefas
# Contexto: o squad está usando esta lista para organizar as tarefas da sprint da semana.
# Missão: adicionem uma nova tarefa à lista usando .append() e exibam a lista completa com o total de itens.

tarefas = ["Estudar Python", "Praticar Git", "Fazer exercícios"]

# escrevam o código do squad aqui

tarefas.append("Apresentar projeto")   # adiciona nova tarefa à lista

print(f"Lista de tarefas atualizada: ({len(tarefas)})") # conta quantos itens tem na lista e exibe a quantidade

for tarefa in tarefas:
    print(f"- {tarefa}")  # exibe cada tarefa em uma linha separada


# Após testar: git add squad_a.py → git commit -m "Squad A: adiciona nova tarefa" → git push
# Out:
# Lista de tarefas atualizada: (4)
# - Estudar Python
# - Praticar Git
# - Fazer exercícios
# - Apresentar projeto

# %%
# SQUAD B — Cadastro de produtos
# Contexto: esta é a lista de produtos já cadastrados na loja.
# Missão: adicionem um produto novo (dicionário com "nome" e "preco") à lista e exibam todos os produtos com seus preços.

cadastro_produtos = [
    {"nome": "Mouse", "preco": 45.0},
    {"nome": "Teclado", "preco": 89.0},
]

# escrevam o código do squad aqui


# Após testar: git add squad_b.py → git commit -m "Squad B: adiciona novo produto" → git push

# %%
# SQUAD C — Lista de compras
# Contexto: alguém digitou o mesmo item duas vezes por engano na lista de compras.
# Missão: removam a duplicata e exibam a lista final corrigida.

lista_de_compras = ["arroz", "feijão", "leite", "arroz"]

# escrevam o código do squad aqui


# Após testar: git add squad_c.py → git commit -m "Squad C: remove item duplicado" → git push

# %%
# SQUAD D — Agenda de contatos
# Contexto: o telefone deste contato mudou e a agenda está desatualizada.
# Missão: atualizem o valor da chave "telefone" e exibam a agenda atualizada.

agenda = {
    "nome": "Joana Silva",
    "telefone": "(11) 0000-0000",  # telefone desatualizado
}

# escrevam o código do squad aqui


# Após testar: git add squad_d.py → git commit -m "Squad D: atualiza telefone do contato" → git push

# %%
# SQUAD E — Estoque
# Contexto: o relatório de valor total do estoque está saindo com um número errado.
# Missão: encontrem o bug no cálculo abaixo e corrijam para que o total considere preço x quantidade.

estoque = [
    ("Caderno", 12.5, 10),   # (produto, preco, quantidade) -- tupla, não dá para editar os itens
    ("Lápis", 2.0, 30),
]

total = 0
for produto, preco, quantidade in estoque:
    total = total + preco   # há um bug nesta linha

print(f"Total em estoque: R$ {total}")

# Após testar: git add squad_e.py → git commit -m "Squad E: corrige cálculo do total do estoque" → git push

# %% [markdown]
# ### 🗣️ Debate coletivo (após as apresentações)
#
# Depois que todos os squads apresentarem, discuta com a turma:
#
# - Qual squad teve o histórico de commits mais claro e fácil de entender?
# - Algum squad teve "conflito" ao juntar o trabalho de mais de uma pessoa? Como resolveram?
# - Por que versionar em pequenos passos (commits) é melhor do que um único commit gigante no final?

# %% [markdown]
# ### Desafio (opcional)
#
# Pratique localmente (fora do Colab): crie uma branch nova a partir da sua branch `alunos/seu-nome`, faça uma alteração no carrinho de compras, comente e dê commit nessa branch.

# %% [markdown]
# ---
# ### Assinatura
#
# Curso: **Análise de Dados com Python — SENAI (Turma T5)**
# Semana 03 — Versionamento (Git/GitHub) e Python Local
#
# *Prof. Especialista Cláudio F. Neves*
